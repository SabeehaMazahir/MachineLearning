# %% [markdown]
# <a href="https://colab.research.google.com/github/SabeehaMazahir/MachineLearning/blob/main/ML_CW_NEW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Import and install necessary libraries

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.10/dist-packages (0.0.6)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.25.2)

# %% [markdown]
# #### Import UCI dataset

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
adult = fetch_ucirepo(id=2)

# data (as pandas dataframes)
X = adult.data.features
y = adult.data.targets

# metadata
print(adult.metadata)

# variable information
print(adult.variables)
# Out:
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Mon Aug 07 2023', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': 'Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))\r\n\r\nPrediction task is to determine whether a person makes over 50K a year.\r\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Listing of attributes:\r\n\r\n>50K, <=50K.\r\n\r\nage: continuous.\r\nworkclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.\r\nfnlwgt: continuous.\r\neducation: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.\r\neducation-num: continuous.\r\nmarital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.\r\noccupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.\r\nrelationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.\r\nrace: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.\r\nsex: Female, Male.\r\ncapital-gain: continuous.\r\ncapital-loss: continuous.\r\nhours-per-week: continuous.\r\nnative-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.', 'citation': None}}
#               name     role         type      demographic  \
# 0              age  Feature      Integer              Age
# 1        workclass  Feature  Categorical           Income
# 2           fnlwgt  Feature      Integer             None
# 3        education  Feature  Categorical  Education Level
# 4    education-num  Feature      Integer  Education Level
# 5   marital-status  Feature  Categorical            Other
# 6       occupation  Feature  Categorical            Other
# 7     relationship  Feature  Categorical            Other
# 8             race  Feature  Categorical             Race
# 9              sex  Feature       Binary              Sex
# 10    capital-gain  Feature      Integer             None
# 11    capital-loss  Feature      Integer             None
# 12  hours-per-week  Feature      Integer             None
# 13  native-country  Feature  Categorical            Other
# 14          income   Target       Binary           Income
#
#                                           description units missing_values
# 0                                                 N/A  None             no
# 1   Private, Self-emp-not-inc, Self-emp-inc, Feder...  None            yes
# 2                                                None  None             no
# 3    Bachelors, Some-college, 11th, HS-grad, Prof-...  None             no
# 4                                                None  None             no
# 5   Married-civ-spouse, Divorced, Never-married, S...  None             no
# 6   Tech-support, Craft-repair, Other-service, Sal...  None            yes
# 7   Wife, Own-child, Husband, Not-in-family, Other...  None             no
# 8   White, Asian-Pac-Islander, Amer-Indian-Eskimo,...  None             no
# 9                                       Female, Male.  None             no
# 10                                               None  None             no
# 11                                               None  None             no
# 12                                               None  None             no
# 13  United-States, Cambodia, England, Puerto-Rico,...  None            yes
# 14                                       >50K, <=50K.  None             no

# %% [markdown]
# #### Load the dataset

# %%
adult.metadata.target_col
# Out:
# ['income']

# %%
adult.metadata.additional_info.summary
# Out:
# 'Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))\r\n\r\nPrediction task is to determine whether a person makes over 50K a year.\r\n'

# %%
adult.data.features
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                NaN  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female             0             0              36
# 48838               Black    Male             0             0              40
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country
# 0      United-States
# 1      United-States
# 2      United-States
# 3      United-States
# 4               Cuba
# ...              ...
# 48837  United-States
# 48838  United-States
# 48839  United-States
# 48840  United-States
# 48841  United-States
#
# [48842 rows x 14 columns]

# %%
adult.data.targets
# Out:
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 48837  <=50K.
# 48838  <=50K.
# 48839  <=50K.
# 48840  <=50K.
# 48841   >50K.
#
# [48842 rows x 1 columns]

# %%
df = adult.data.original

# %%
df
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                NaN  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female             0             0              36
# 48838               Black    Male             0             0              40
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country  income
# 0      United-States   <=50K
# 1      United-States   <=50K
# 2      United-States   <=50K
# 3      United-States   <=50K
# 4               Cuba   <=50K
# ...              ...     ...
# 48837  United-States  <=50K.
# 48838  United-States  <=50K.
# 48839  United-States  <=50K.
# 48840  United-States  <=50K.
# 48841  United-States   >50K.
#
# [48842 rows x 15 columns]

# %%
adult.data.headers
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# df = pd.read_csv('https://archive.ics.uci.edu/dataset/2/adult')

# # Load the dataset
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)

# # Assign column names
# column_names = [
#     "age", "workclass", "fnlwgt", "education", "education-num",
#     "marital-status", "occupation", "relationship", "race", "sex",
#     "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"
# ]
# df.columns = column_names

# %%
adult.variables
# Out:
#               name     role         type      demographic  \
# 0              age  Feature      Integer              Age
# 1        workclass  Feature  Categorical           Income
# 2           fnlwgt  Feature      Integer             None
# 3        education  Feature  Categorical  Education Level
# 4    education-num  Feature      Integer  Education Level
# 5   marital-status  Feature  Categorical            Other
# 6       occupation  Feature  Categorical            Other
# 7     relationship  Feature  Categorical            Other
# 8             race  Feature  Categorical             Race
# 9              sex  Feature       Binary              Sex
# 10    capital-gain  Feature      Integer             None
# 11    capital-loss  Feature      Integer             None
# 12  hours-per-week  Feature      Integer             None
# 13  native-country  Feature  Categorical            Other
# 14          income   Target       Binary           Income
#
#                                           description units missing_values
# 0                                                 N/A  None             no
# 1   Private, Self-emp-not-inc, Self-emp-inc, Feder...  None            yes
# 2                                                None  None             no
# 3    Bachelors, Some-college, 11th, HS-grad, Prof-...  None             no
# 4                                                None  None             no
# 5   Married-civ-spouse, Divorced, Never-married, S...  None             no
# 6   Tech-support, Craft-repair, Other-service, Sal...  None            yes
# 7   Wife, Own-child, Husband, Not-in-family, Other...  None             no
# 8   White, Asian-Pac-Islander, Amer-Indian-Eskimo,...  None             no
# 9                                       Female, Male.  None             no
# 10                                               None  None             no
# 11                                               None  None             no
# 12                                               None  None             no
# 13  United-States, Cambodia, England, Puerto-Rico,...  None            yes
# 14                                       >50K, <=50K.  None             no

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       47879 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      47876 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48568 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
# number of null values
df.isnull().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
# number ofunique values in each column
df.nunique()
# Out:
# age                  74
# workclass             9
# fnlwgt            28523
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        123
# capital-loss         99
# hours-per-week       96
# native-country       42
# income                4
# dtype: int64

# %%
# .T trnasposes the table, so rows become columns, optional, makes it easier to read
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             48842.0      38.643585      13.710510     17.0      28.0
# fnlwgt          48842.0  189664.134597  105604.025423  12285.0  117550.5
# education-num   48842.0      10.078089       2.570973      1.0       9.0
# capital-gain    48842.0    1079.067626    7452.019058      0.0       0.0
# capital-loss    48842.0      87.502314     403.004552      0.0       0.0
# hours-per-week  48842.0      40.422382      12.391444      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178144.5  237642.0  1490400.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %%
df['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# ?                    1836
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# ?                    1843
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# ?                               583
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
df['income'].value_counts()
# Out:
# <=50K     24720
# <=50K.    12435
# >50K       7841
# >50K.      3846
# Name: income, dtype: int64

# %%
# Replace the income values to ensure consistency
df['income'] = df['income'].replace({'<=50K.': '<=50K', '>50K.': '>50K'})

# Verify the changes
print(df['income'].value_counts())
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 48

# %%
df.isnull().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
# dropping duplicates
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (48794, 15)

# %%
sns.countplot(x='income', palette='coolwarm', hue='race', data=df)
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
# filling the missing values
# method - replacing the values with the mode of each class

# %%
df['workclass'] = df['workclass'].replace('?', 'Private')
df['occupation'] = df['occupation'].replace('?', 'Prof-specialty')
df['native-country'] = df['native-country'].replace('?', 'United-States')
# Out:
# <ipython-input-99-6f5fa00c80f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['workclass'] = df['workclass'].replace('?', 'Private')
# <ipython-input-99-6f5fa00c80f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['occupation'] = df['occupation'].replace('?', 'Prof-specialty')
# <ipython-input-99-6f5fa00c80f3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['native-country'] = df['native-country'].replace('?', 'United-States')

# %%
# filling missing values - categorical data filled with the mode
# df['workclass'] = df['workclass'].fillna(df['workclass'].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# df['occupation'] = df['occupation'].fillna(df['occupation'].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# df['native-country'] = df['native-country'].fillna(df['native-country'].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df.drop_duplicates()
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64           Private  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed     Prof-specialty  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female             0             0              36
# 48838               Black    Male             0             0              40
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 48837  United-States  <=50K
# 48838  United-States  <=50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K
#
# [44669 rows x 15 columns]

# %%
# Plot a histogram
plt.hist(df['age'], bins=10, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Visualize the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-107-5e1c43acbdbb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Boxplot
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True)
# Out:
# age                  Axes(0.125,0.653529;0.227941x0.226471)
# fnlwgt            Axes(0.398529,0.653529;0.227941x0.226471)
# education-num     Axes(0.672059,0.653529;0.227941x0.226471)
# capital-gain         Axes(0.125,0.381765;0.227941x0.226471)
# capital-loss      Axes(0.398529,0.381765;0.227941x0.226471)
# hours-per-week    Axes(0.672059,0.381765;0.227941x0.226471)
# dtype: object

# %%
from scipy import stats

# Calculate the Z-scores
z_scores = stats.zscore(df['age'])

# Define a threshold for outlier detection
threshold = 3

# Identify outliers
outliers = df[abs(z_scores) > threshold]

# Display the outliers
print(outliers)
outliers.shape[0]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 74      79           Private  124744  Some-college             10
# 3338    79           Private  144533       HS-grad              9
# 4720    79  Self-emp-not-inc  158319       HS-grad              9
# 6000    79         Local-gov   84616          11th              7
# 6173    79           Private  120707     Doctorate             16
# 8176    79           Private  121318  Some-college             10
# 8522    79           Private  333230       HS-grad              9
# 11099   79           Private  165209       HS-grad              9
# 11532   79           Private  142370   Prof-school             15
# 14903   79      Self-emp-inc  309272       HS-grad              9
# 16523   79           Private  163140       HS-grad              9
# 17609   79      Self-emp-inc   97082          12th              8
# 18141   79  Self-emp-not-inc   84979     Assoc-voc             11
# 19828   79           Private  172220       7th-8th              4
# 20483   79         Local-gov  146244     Doctorate             16
# 20880   79           Private  142171       7th-8th              4
# 21343   79           Private  266119     Bachelors             13
# 23900   79  Self-emp-not-inc  103684       HS-grad              9
# 25163   79           Private   76641       Masters             14
# 26242   79      Self-emp-inc  183686     Bachelors             13
# 28176   79       Federal-gov   62176     Doctorate             16
# 32754   79           Private   48574       7th-8th              4
# 33487   79           Private   27457       Masters             14
# 42330   79           Private  160758       7th-8th              4
# 43850   79           Private  149912     Bachelors             13
# 43971   79           Private  187492       HS-grad              9
# 44442   79           Private   23275          10th              6
# 44501   79           Private  121552       7th-8th              4
# 48709   79         Local-gov  132668       HS-grad              9
#
#               marital-status       occupation    relationship   race     sex  \
# 74        Married-civ-spouse   Prof-specialty  Other-relative  White    Male
# 3338                 Widowed   Prof-specialty   Not-in-family  Black  Female
# 4720                 Widowed    Other-service   Not-in-family  White  Female
# 6000      Married-civ-spouse  Exec-managerial         Husband  White    Male
# 6173      Married-civ-spouse   Prof-specialty         Husband  White    Male
# 8176      Married-civ-spouse     Adm-clerical         Husband  White    Male
# 8522   Married-spouse-absent   Prof-specialty   Not-in-family  White    Male
# 11099     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 11532     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 14903     Married-civ-spouse  Exec-managerial         Husband  White    Male
# 16523     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 17609                Widowed            Sales   Not-in-family  White    Male
# 18141     Married-civ-spouse            Sales         Husband  White    Male
# 19828                Widowed  Priv-house-serv   Not-in-family  White  Female
# 20483                Widowed   Prof-specialty       Unmarried  White  Female
# 20880     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 21343     Married-civ-spouse            Sales         Husband  White    Male
# 23900     Married-civ-spouse  Farming-fishing         Husband  White    Male
# 25163     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 26242     Married-civ-spouse            Sales         Husband  White    Male
# 28176                Widowed  Exec-managerial   Not-in-family  White    Male
# 32754                Widowed   Prof-specialty   Not-in-family  White    Male
# 33487          Never-married   Prof-specialty   Not-in-family  White  Female
# 42330     Married-civ-spouse            Sales         Husband  White    Male
# 43850          Never-married    Other-service   Not-in-family  White  Female
# 43971     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 44442     Married-civ-spouse   Prof-specialty         Husband  White    Male
# 44501                Widowed    Other-service       Unmarried  Black    Male
# 48709     Married-civ-spouse            Sales         Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 74                0             0              20  United-States  <=50K
# 3338              0             0              30  United-States  <=50K
# 4720              0             0              24  United-States  <=50K
# 6000              0             0               7  United-States  <=50K
# 6173          20051             0              35    El-Salvador   >50K
# 8176              0             0              20  United-States  <=50K
# 8522              0             0               6  United-States  <=50K
# 11099             0             0              40  United-States  <=50K
# 11532             0             0              10  United-States  <=50K
# 14903             0             0              40  United-States   >50K
# 16523             0             0              40  United-States   >50K
# 17609         18481             0              45  United-States   >50K
# 18141             0             0              20  United-States   >50K
# 19828          2964             0              30  United-States  <=50K
# 20483             0             0              40  United-States  <=50K
# 20880          1409             0              35  United-States  <=50K
# 21343             0             0              40  United-States  <=50K
# 23900             0             0              40  United-States  <=50K
# 25163         20051             0              40         Poland   >50K
# 26242             0             0              20  United-States   >50K
# 28176             0             0               6  United-States   >50K
# 32754             0             0              40  United-States  <=50K
# 33487             0             0              23  United-States  <=50K
# 42330             0             0              15  United-States  <=50K
# 43850             0             0              40  United-States  <=50K
# 43971             0             0               7  United-States  <=50K
# 44442             0             0              20  United-States  <=50K
# 44501             0             0               5  United-States  <=50K
# 48709             0             0              15  United-States  <=50K
# 29

# %%
import pandas as pd

# Assuming df is your DataFrame

# Create a boolean mask where '?' appears
mask = df.applymap(lambda x: x == '?')

# Count the number of True values in the mask (i.e., the number of '?' in the DataFrame)
num_question_marks = mask.sum().sum()

print("Number of '?' in the DataFrame:", num_question_marks)
# Out:
# Number of '?' in the DataFrame: 0

# %%
# Boxplot
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True)
# Out:
# age                  Axes(0.125,0.653529;0.227941x0.226471)
# fnlwgt            Axes(0.398529,0.653529;0.227941x0.226471)
# education-num     Axes(0.672059,0.653529;0.227941x0.226471)
# capital-gain         Axes(0.125,0.381765;0.227941x0.226471)
# capital-loss      Axes(0.398529,0.381765;0.227941x0.226471)
# hours-per-week    Axes(0.672059,0.381765;0.227941x0.226471)
# dtype: object

# %%
# Feature engineering

# %%
df['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
# feature engineering - marital status: We make it simpler by reducing the categories
df['marital-status'] = df['marital-status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
df['marital-status'] = df['marital-status'].replace(['Never-married', 'not-married'])
df['marital-status'] = df['marital-status'].replace(['Married-spouse-absent', 'Divorced', 'Separated', 'Widowed'], 'other')

# %%
# feature engineering on: income - convert to numeric as 0s and 1s
df.income = df.income.replace(['<=50K'], 0)
df.income = df.income.replace(['>50K'], 1)

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country  income
# 0     Male          2174             0              40   United-States   <=50K
# 1     Male             0             0              13   United-States   <=50K
# 2     Male             0             0              40   United-States   <=50K
# 3     Male             0             0              40   United-States   <=50K
# 4   Female             0             0              40            Cuba   <=50K
# 5   Female             0             0              40   United-States   <=50K
# 6   Female             0             0              16         Jamaica   <=50K
# 7     Male             0             0              45   United-States    >50K
# 8   Female         14084             0              50   United-States    >50K
# 9     Male          5178             0              40   United-States    >50K

# %%
# correlation is for numeric data
df.corr()

# we can see that there is no high correlation, only normal to moderate correlation among variables. We dont have to be concerned about this.
# Out:
# <ipython-input-28-de652c8a4874>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <ipython-input-29-fe43fffaf13b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <Axes: >

# %%
df.hist(figsize =(12,12), layout=(3,3))  # plots the histogram for the entire numeric data
# layout 3 rows, 3 cols
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'fnlwgt'}>,
#         <Axes: title={'center': 'education-num'}>],
#        [<Axes: title={'center': 'capital-gain'}>,
#         <Axes: title={'center': 'capital-loss'}>,
#         <Axes: title={'center': 'hours-per-week'}>],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
# Boxplot
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True)
# Out:
# age                  Axes(0.125,0.653529;0.227941x0.226471)
# fnlwgt            Axes(0.398529,0.653529;0.227941x0.226471)
# education-num     Axes(0.672059,0.653529;0.227941x0.226471)
# capital-gain         Axes(0.125,0.381765;0.227941x0.226471)
# capital-loss      Axes(0.398529,0.381765;0.227941x0.226471)
# hours-per-week    Axes(0.672059,0.381765;0.227941x0.226471)
# dtype: object

# %%
# Model building
x = df.drop(['income'], axis=1)
y = df['income']

# %%
# Feature scaling - to make sure all values are of the same magnitude and non are give more importance

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# LabelEncoder - converts the categorical variables to numeric and machine readable format
df1 = df.copy()
df1 = df1.apply(LabelEncoder().fit_transform)
df1.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   22          7    2671          9             12               4
# 1   33          6    2926          9             12               2
# 2   21          4   14086         11              8               0
# 3   36          4   15336          1              6               2
# 4   11          4   19355          9             12               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           1             1     4    1            25             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours-per-week  native-country  income
# 0              39              39       0
# 1              12              39       0
# 2              39              39       0
# 3              39              39       0
# 4              39               5       0

# %%
ss = StandardScaler().fit(df1.drop('income', axis=1))

# %%
x = ss.transform(df1.drop('income', axis=1))
y = df['income']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
# NAIVE BAYES
from sklearn.naive_bayes import GaussianNB

# %%
# train the model
nbc = GaussianNB()
nbc.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# evaluate our model
prediction = nbc.predict(x_test)

# %%
print("Accuracy on training data: ", nbc.score(x_train, y_train))
print("Accuracy on testing data: ", nbc. score(x_test, y_test))
# Out:
# Accuracy on training data:  0.8246753246753247
# Accuracy on testing data:  0.8141058450199611

# %%
print(confusion_matrix(y_test, prediction))
# Out:
# [[6864  533]
#  [1283 1089]]

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.84      0.93      0.88      7397
#         >50K       0.67      0.46      0.55      2372
#
#     accuracy                           0.81      9769
#    macro avg       0.76      0.69      0.71      9769
# weighted avg       0.80      0.81      0.80      9769

# %%
from sklearn.metrics import accuracy_score

# %%
# RANDOM FOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

model1 = rfc.fit(x_train, y_train)
prediction1 = model1.predict(x_test)

print("Accuracy on training data: ", rfc.score(x_train, y_train))
print("Accuracy on testing data: ", rfc. score(x_test, y_test))
# Out:
# Accuracy on training data:  0.9999122499122499
# Accuracy on testing data:  0.8543351417750026

# %%
print(confusion_matrix(y_test, prediction1))
# Out:
# [[6888  509]
#  [ 914 1458]]

# %%
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.93      0.91      7397
#         >50K       0.74      0.61      0.67      2372
#
#     accuracy                           0.85      9769
#    macro avg       0.81      0.77      0.79      9769
# weighted avg       0.85      0.85      0.85      9769
